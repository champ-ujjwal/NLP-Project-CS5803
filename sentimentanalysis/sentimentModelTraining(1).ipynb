# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('text_emotion.csv', usecols=['sentiment', 'content'])

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

nltk.download('stopwords')
nltk.download('punkt')

stop_words = set(stopwords.words('english'))

def preprocess_text(text):
    # Lowercase the text
    text = text.lower()
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stop words
    tokens = [word for word in tokens if word not in stop_words]
    # Reconstruct the text
    text = ' '.join(tokens)
    return text

# Apply preprocessing to the content column
df['content'] = df['content'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\91628\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\91628\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df['content'], df['sentiment'], test_size=0.2, random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# Initialize the model
model = LogisticRegression()

# Train the model
model.fit(X_train_tfidf, y_train)
# Out:
# C:\Users\91628\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import classification_report

# Make predictions on the testing data
y_pred = model.predict(X_test_tfidf)

# Evaluate the model
print(classification_report(y_test, y_pred))
# Out:
# C:\Users\91628\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#        anger       0.00      0.00      0.00        19
#      boredom       0.00      0.00      0.00        31
#        empty       0.50      0.01      0.02       162
#   enthusiasm       0.00      0.00      0.00       163
#          fun       0.09      0.01      0.03       338
#    happiness       0.33      0.39      0.36      1028
#         hate       0.52      0.18      0.26       268
#         love       0.49      0.39      0.44       762
#      neutral       0.34      0.53      0.41      1740
#       relief       0.42      0.03      0.06       352
# ...

# %%
def predict_sentiment(text):
    # Preprocess the text
    preprocessed_text = preprocess_text(text)
    # Convert the text to TF-IDF features
    text_tfidf = tfidf_vectorizer.transform([preprocessed_text])
    # Predict sentiment
    sentiment = model.predict(text_tfidf)
    return sentiment[0]

results = []

# Read input sentences from test.hypo file, predict sentiment, and store in list
with open('test.hypo', 'r') as f:
    for line in f:
        sentence = line.strip()
        predicted_sentiment = predict_sentiment(sentence)
        results.append((sentence, predicted_sentiment))

# Convert the list to a DataFrame
results_df.to_csv('sentiments.csv', index=False, float_format='%.10g')

# Save DataFrame to CSV file
results_df.to_csv('sentiments.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 20
#      17         results.append((sentence, predicted_sentiment))
#      19 # Convert the list to a DataFrame
# ---> 20 results_df.to_csv('sentiments.csv', index=False, float_format='%.10g')
#      22 # Save DataFrame to CSV file
#      23 results_df.to_csv('sentiments.csv', index=False)
#
# NameError: name 'results_df' is not defined
